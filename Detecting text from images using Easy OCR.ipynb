# %% [markdown]
# ## Importing Libraries

# %%
import easyocr
import PIL
from PIL import ImageDraw

# %%
#setting IMAGE_PATH to read the image containing text
IMAGE_PATH ="image_1.PNG"
# displaying image to be used for OCR detection
im1 = PIL.Image.open(IMAGE_PATH)
im1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=565x370 at 0x2265E64F100>

# %% [markdown]
# ## Detecting text from images with bounding boxes and probability

# %%
#creating reader object out of easyocr
reader_en = easyocr.Reader(['en']) 
res = reader_en.readtext(IMAGE_PATH,paragraph=False)
#printing result
print(res)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...

# %% [markdown]
# ## Detecting Plain Text with no details

# %%
res = reader.readtext(IMAGE_PATH,detail=0,paragraph=True)
print(res)
# Out:
# ['PLEASE  TAKE NOTHING BUT PICTURES LEAVE NOTHING FOOT PRINTS BUT']

# %%
reader = easyocr.Reader(['fr'],gpu=False) 
res = reader.readtext('image6.jpg',paragraph=False)
print(res)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[204, 248], [536, 248], [536, 370], [204, 370]], 'LA VIE EST', 0.5601771427103025), ([[158, 364], [564, 364], [564, 488], [158, 488]], 'UN SOMMEIL,', 0.8780018549087643), ([[545, 453], [563, 453], [563, 479], [545, 479]], '9', 0.9960414086001492), ([[176, 478], [562, 478], [562, 600], [176, 600]], "L'AMOUR EN", 0.6126281822581647), ([[185, 593], [541, 593], [541, 705], [185, 705]], 'ESTLE REVE', 0.8111532864853317), ([[216, 1013], [549, 1013], [549, 1082], [216, 1082]], 'Alhed de Musset', 0.3817713094434601)]

# %%
import PIL
from PIL import ImageDraw, ImageFont
im = PIL.Image.open("image6.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=735x1102 at 0x2265DFD1CD0>

# %%
bounds = reader.readtext('image6.jpg')
bounds
# Out:
# [([[204, 248], [536, 248], [536, 370], [204, 370]],
#   'LA VIE EST',
#   0.5601771427103025),
#  ([[158, 364], [564, 364], [564, 488], [158, 488]],
#   'UN SOMMEIL,',
#   0.8780018549087643),
#  ([[545, 453], [563, 453], [563, 479], [545, 479]], '9', 0.9960414086001492),
#  ([[176, 478], [562, 478], [562, 600], [176, 600]],
#   "L'AMOUR EN",
#   0.6126281822581647),
#  ([[185, 593], [541, 593], [541, 705], [185, 705]],
#   'ESTLE REVE',
#   0.8111532864853317),
#  ([[216, 1013], [549, 1013], [549, 1082], [216, 1082]],
#   'Alhed de Musset',
#   0.3817713094434601)]

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=735x1102 at 0x2265DFD1CD0>

# %%
bounds1 = reader_en.readtext(IMAGE_PATH)


draw_boxes(im1, bounds1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=565x370 at 0x2265E64F100>
